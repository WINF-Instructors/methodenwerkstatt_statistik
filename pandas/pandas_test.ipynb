# %%
import pandas as pd
df = pd.read_csv("apartment_cost_list.csv")
df
# Out:
#            Job #    Borough House #          Street Name  Block  Lot    Bin #  \
# 0      123768976  MANHATTAN    1598           2ND AVENUE   1545   49  1049907
# 1      140922893  MANHATTAN     160              E 89 ST   1517   43  1048094
# 2      301773579   BROOKLYN      65         GATES AVENUE   1962   86  3056039
# 3      301976057   BROOKLYN    1401         OCEAN AVENUE   7584   35  3206621
# 4      301989276   BROOKLYN     154         NOBLE STREET   2573   10  3065099
# ...          ...        ...     ...                  ...    ...  ...      ...
# 19608  122923649  MANHATTAN     315     WEST 33RD STREET    757   22  1013552
# 19609  121090112  MANHATTAN     110         DUANE STREET    150   22  1001645
# 19610  102937342  MANHATTAN     166          BANK STREET    638    4  1078335
# 19611  200838558      BRONX    2762  KINGSBRIDGE TERRACE   3253   90  2015521
# 19612  301429158   BROOKLYN     802        HOWARD AVENUE   3565   42  3081797
#
# ...

# %%
df = df[["Borough", "Initial Cost"]]
df
# Out:
#          Borough Initial Cost
# 0      MANHATTAN    $65000.00
# 1      MANHATTAN    $85000.00
# 2       BROOKLYN    $60000.00
# 3       BROOKLYN    $75000.00
# 4       BROOKLYN    $40000.00
# ...          ...          ...
# 19608  MANHATTAN    $60000.00
# 19609  MANHATTAN    $40000.00
# 19610  MANHATTAN    $80000.00
# 19611      BRONX    $40000.00
# 19612   BROOKLYN    $60000.00
#
# [19613 rows x 2 columns]

# %%
df.describe()
# Out:
#           Borough Initial Cost
# count       19613        19613
# unique          5           46
# top     MANHATTAN    $40000.00
# freq        15341         2877

# %%
df["Initial Cost"]=df["Initial Cost"].str[1:]
df
# Out:
# /tmp/ipykernel_25654/3285724413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Initial Cost"]=df["Initial Cost"].str[1:]
#          Borough Initial Cost
# 0      MANHATTAN     65000.00
# 1      MANHATTAN     85000.00
# 2       BROOKLYN     60000.00
# 3       BROOKLYN     75000.00
# 4       BROOKLYN     40000.00
# ...          ...          ...
# 19608  MANHATTAN     60000.00
# 19609  MANHATTAN     40000.00
# 19610  MANHATTAN     80000.00
# 19611      BRONX     40000.00
# 19612   BROOKLYN     60000.00
#
# [19613 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19613 entries, 0 to 19612
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       19613 non-null  object
#  1   Initial Cost  19613 non-null  object
# dtypes: object(2)
# memory usage: 306.6+ KB

# %%
df["Initial Cost"]=df["Initial Cost"].apply(pd.to_numeric)
# Out:
# /tmp/ipykernel_25654/593237812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Initial Cost"]=df["Initial Cost"].apply(pd.to_numeric)

# %%
df.groupby("Borough").agg("mean")
# Out:
#                Initial Cost
# Borough
# BRONX          61593.856655
# BROOKLYN       59762.428977
# MANHATTAN      59352.714947
# QUEENS         58391.826923
# STATEN ISLAND  61631.578947
